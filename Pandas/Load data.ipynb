# %%
import pandas as pd
#Read csv file using pandas
df = pd.read_csv('csv files/submission.csv')
df
# Out:
#      Unnamed: 0  data
# 0             0     0
# 1             1     1
# 2             2     2
# 3             3     3
# 4             4     4
# ..          ...   ...
# 995         995   995
# 996         996   996
# 997         997   997
# 998         998   998
# 999         999   999
#
# [1000 rows x 2 columns]

# %%
df.shape
# Out:
# (1000, 2)

# %%
#in order to display the max no. of rows and columns we use a method
pd.set_option('display.max_rows', 1000 )
df
# Out:
#      Unnamed: 0  data
# 0             0     0
# 1             1     1
# 2             2     2
# 3             3     3
# 4             4     4
# 5             5     5
# 6             6     6
# 7             7     7
# 8             8     8
# 9             9     9
# 10           10    10
# 11           11    11
# 12           12    12
# 13           13    13
# 14           14    14
# 15           15    15
# 16           16    16
# 17           17    17
# 18           18    18
# 19           19    19
# 20           20    20
# 21           21    21
# 22           22    22
# 23           23    23
# 24           24    24
# 25           25    25
# 26           26    26
# 27           27    27
# 28           28    28
# 29           29    29
# 30           30    30
# 31           31    31
# 32           32    32
# 33           33    33
# 34           34    34
# 35           35    35
# 36           36    36
# 37           37    37
# 38           38    38
# 39           39    39
# ...

# %%
#in order to load only the head and tail of the data
df.head(10)
# Out:
#    Unnamed: 0  data
# 0           0     0
# 1           1     1
# 2           2     2
# 3           3     3
# 4           4     4
# 5           5     5
# 6           6     6
# 7           7     7
# 8           8     8
# 9           9     9

# %%
df.tail()
# Out:
#      Unnamed: 0  data
# 995         995   995
# 996         996   996
# 997         997   997
# 998         998   998
# 999         999   999
